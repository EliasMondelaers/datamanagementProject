# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\links.csv")
df1
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0
#
# [45843 rows x 3 columns]

# %%
df2 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\credits.csv")
df2
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
#Merge df1 and df2 
merged_df = pd.merge(
    df1, 
    df2, 
    left_on='movieId', 
    right_on='id', 
    how='left' 
)
merged_df
# Out:
#        movieId   imdbId    tmdbId  \
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45844   176269  6209470  439050.0
# 45845   176271  2028550  111109.0
# 45846   176273   303758   67758.0
# 45847   176275     8536  227506.0
# 45848   176279  6980792  461257.0
#
#                                                     cast  \
# 0                                                    NaN
# 1      [{'cast_id': 3, 'character': 'Taisto Olavi Kas...
# 2      [{'cast_id': 5, 'character': 'Nikander', 'cred...
# 3                                                    NaN
# 4      [{'cast_id': 42, 'character': 'Ted the Bellhop...
# ...                                                  ...
# 45844                                                NaN
# 45845                                                NaN
# ...

# %%
df3 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\ratings.csv")
df3
# Out:
#           userId  movieId  rating   timestamp
# 0              1      110     1.0  1425941529
# 1              1      147     4.5  1425942435
# 2              1      858     5.0  1425941523
# 3              1     1221     5.0  1425941546
# 4              1     1246     5.0  1425941556
# ...          ...      ...     ...         ...
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858
#
# [26024289 rows x 4 columns]

# %%
df4 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\movies_metadata.csv")
df4
# Out:
# 45466
# C:\Users\elias\AppData\Local\Temp\ipykernel_20428\955170608.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\movies_metadata.csv")

# %%
df4['imdb_id'].isnull().sum()
df4['id'] = pd.to_numeric(df4['id'], errors='coerce')

# tt0101704
# tt0358146
# tt0065908
# tt0818098
# tt0176311
# tt1762399
# tt2701582
# tt1325753
# tt0119501
# tt0105298
# tt0493101
# tt13139218
# tt6618142
# tt1147516
# tt0491603
# tt4699464
# tt6051554
# Out:
# 17

# %% [markdown]
# Impute imdb ID for the missing rows there are only 17 rows to impute

# %%
correct_imdb_ids = [
    'tt0101704', 'tt0358146', 'tt0065908', 'tt0818098', 'tt0176311',
    'tt1762399', 'tt2701582', 'tt1325753', 'tt0119501', 'tt0105298',
    'tt0493101', 'tt13139218', 'tt6618142', 'tt1147516', 'tt0491603',
    'tt4699464', 'tt6051554'
]
missing_mask = df4['imdb_id'].isnull()
missing_indices = df4[missing_mask].index
new_ids_series = pd.Series(correct_imdb_ids, index=missing_indices)

df4['imdb_id'].fillna(new_ids_series, inplace=True)
# Out:
# C:\Users\elias\AppData\Local\Temp\ipykernel_20428\2115610915.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4['imdb_id'].fillna(new_ids_series, inplace=True)

# %%
merged_df['full_imdbid'] = 'tt0' + merged_df['imdbId'].astype(str)

final_merged_df = pd.merge(
    merged_df,
    df4,
    left_on='full_imdbid',
    right_on='imdb_id',
    how='inner'
)
final_merged_df

# %%
final_merged_df.to_csv(r'C:\Users\elias\Downloads\Data Management\final.csv', index=False)
