# %%
import pandas as pd
# Out:
# C:\Users\elias\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\elias\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df1 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\links.csv")
df1
# Out:
# 9125

# %%
df2 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\credits.csv")
df2
# Out:
# 45476

# %%
#Merge df1 and df2 
merged_df = pd.merge(
    df1, 
    df2, 
    left_on='movieId', 
    right_on='id', 
    how='left' 
)
merged_df

# %%
df3 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\ratings.csv")
df3

# %%
df4 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\movies_metadata.csv")
df4
# Out:
# 45466
# C:\Users\elias\AppData\Local\Temp\ipykernel_20428\955170608.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv(r"C:\Users\elias\Desktop\HIRB\Liege\Data Management\archive\movies_metadata.csv")

# %%
df4['imdb_id'].isnull().sum()
# Out:
# 17

# %%
df4['id'] = pd.to_numeric(df4['id'], errors='coerce')

# tt0101704
# tt0358146
# tt0065908
# tt0818098
# tt0176311
# tt1762399
# tt2701582
# tt1325753
# tt0119501
# tt0105298
# tt0493101
# tt13139218
# tt6618142
# tt1147516
# tt0491603
# tt4699464
# tt6051554
# Out:
#        adult                              belongs_to_collection   budget  \
# 8966   False                                                NaN  1000000
# 13757  False                                                NaN        0
# 13821  False  {'id': 75014, 'name': 'How I Unleashed World W...        0
# 17382  False                                                NaN  2500000
# 17510  False                                                NaN        0
# 18959  False                                                NaN        0
# 19322  False                                                NaN        0
# 20806  False                                                NaN        0
# 20937  False                                                NaN        0
# 21916  False                                                NaN        0
# 22987  False                                                NaN        0
# 23744  False  {'id': 246207, 'name': 'Gunbuster Collection',...        0
# 33753  False                                                NaN        0
# 36955  False                                                NaN        0
# 40809  False                                                NaN        0
# 41832  False                                                NaN        0
# 45070  False                                                NaN        0
#
#                                                   genres  \
# 8966                       [{'id': 80, 'name': 'Crime'}]
# 13757  [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...
# 13821  [{'id': 10769, 'name': 'Foreign'}, {'id': 28, ...
# 17382  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
# 17510  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 18959  [{'id': 99, 'name': 'Documentary'}, {'id': 16,...
# 19322                                                 []
# 20806  [{'id': 16, 'name': 'Animation'}, {'id': 28, '...
# 20937  [{'id': 37, 'name': 'Western'}, {'id': 28, 'na...
# 21916  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 22987                                                 []
# 23744  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 33753                                                 []
# 36955                                                 []
# 40809  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 41832  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 45070                                                 []
#
#                                            homepage        id imdb_id  \
# 8966                                            NaN   36337.0     NaN
# 13757                                           NaN  200796.0     NaN
# 13821                                           NaN   75015.0     NaN
# 17382  http://www.delawarepictures.net/dreamkiller/   36663.0     NaN
# 17510                                           NaN   47116.0     NaN
# 18959                                           NaN   28500.0     NaN
# 19322                                           NaN  118013.0     NaN
# 20806                                           NaN   15257.0     NaN
# 20937                                           NaN   55576.0     NaN
# 21916                                           NaN  293412.0     NaN
# 22987                                           NaN   45514.0     NaN
# 23744                                           NaN   30146.0     NaN
# 33753                                           NaN  324017.0     NaN
# 36955                                           NaN  161535.0     NaN
# 40809                                           NaN   65256.0     NaN
# 41832                                           NaN  430514.0     NaN
# 45070                                           NaN  439314.0     NaN
#
#       original_language                                     original_title  \
# 8966                 en                                           Delusion
# 13757                pl                                               Show
# 13821                pl  Jak rozpętałem drugą wojnę światową: Cz.3 - Wś...
# 17382                en                                        Dreamkiller
# 17510                en                                              Víťaz
# 18959                en       Before The Dinosaurs - Walking With Monsters
# 19322                en                                          Endeavour
# 20806                en                                 Hulk vs. Wolverine
# 20937                en                          Last Stand at Saber River
# 21916                en                                       Running Wild
# 22987                en                                                  8
# 23744                ja                          トップをねらえ！＆トップをねらえ２！合体劇場版!!
# 33753                en                                         The Master
# 36955                en                                     Doraemon:貓狗時空傳
# 40809                en                     H2O Just Add Water - The Movie
# 41832                fr                                  Le passe-muraille
# 45070                en                     The Garden of Afflictions 2017
#
#                                                 overview  ... release_date  \
# 8966   In this fast-paced, noirish road movie, a comp...  ...   1991-06-07
# 13757                                                NaN  ...   2003-03-19
# 13821  How I Unleashed World War II tells the story o...  ...   1970-04-06
# 17382  A team of doctors experiment with a new, highl...  ...          NaN
# 17510  Tou former boxers meet in the ring again after...  ...   1979-03-09
# 18959  Many people think of the dinosaurs as the firs...  ...   2005-11-05
# 19322  Shaun Evans (The Take) steps into John Thaw's ...  ...          NaN
# 20806  Department H sends in Wolverine to track down ...  ...   2009-01-27
# 20937  As America recovers from the Civil War, one ma...  ...   1997-01-19
# 21916  Jennifer Barker plays a troubled woman who has...  ...   1995-01-01
# 22987  8 shorts centered around 8 themes directed by ...  ...   2008-10-23
# 23744  This double feature comprises of Gunbuster and...  ...   2006-10-01
# 33753  In 19th-century China, during the infamous Qin...  ...   2017-01-01
# 36955  One day, Nobita finds a stray dog drowning in ...  ...   2004-03-06
# 40809  When three normal teenage girls stumble upon a...  ...   2011-10-10
# 41832                                                NaN  ...   2016-12-16
# 45070  Brazilian philosopher Olavo de Carvalho's thin...  ...          NaN
#
#       revenue runtime                                   spoken_languages  \
# 8966      0.0   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13757     0.0     NaN                                                 []
# 13821     0.0    73.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 17382     0.0   110.0                                                 []
# 17510     0.0    78.0                                                 []
# 18959     0.0    87.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 19322     0.0    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 20806     0.0    38.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 20937     0.0     0.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 21916     0.0     0.0                                                 []
# 22987     0.0   100.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 23744     0.0   180.0               [{'iso_639_1': 'ja', 'name': '日本語'}]
# 33753     0.0   109.0                                                 []
# 36955     0.0     0.0                                                 []
# 40809     0.0    91.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 41832     0.0     NaN          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 45070     0.0     0.0                                                 []
#
#          status                                            tagline  \
# 8966   Released  She only wanted love. But money's better than ...
# 13757  Released                                                NaN
# 13821  Released                                                NaN
# 17382  Released                       Fear is the greatest killer.
# 17510   Rumored                                                NaN
# 18959  Released                                                NaN
# 19322  Released  Rookie detective Endeavor Morse faces his firs...
# 20806  Released                                                NaN
# 20937  Released                                                NaN
# 21916  Released                                                NaN
# 22987   Rumored                                                NaN
# 23744  Released                                                NaN
# 33753  Released                                                NaN
# 36955  Released                                                NaN
# 40809  Released                        Do you believe in mermaids?
# 41832  Released                                                NaN
# 45070  Released                                                NaN
#
#                                                    title  video vote_average  \
# 8966                                            Delusion  False          4.8
# 13757                                               Show  False          6.3
# 13821  How I Unleashed World War II Part III: Among F...  False          7.0
# 17382                                        Dreamkiller  False          5.0
# 17510                                         The Winner  False          0.0
# 18959       Before The Dinosaurs - Walking With Monsters  False          7.3
# 19322                                          Endeavour  False          6.6
# 20806                                 Hulk vs. Wolverine  False          6.8
# 20937                          Last Stand at Saber River  False          3.7
# 21916                                       Running Wild  False         10.0
# 22987                                                  8  False          0.0
# 23744  Gunbuster vs Diebuster Aim for the Top! The GA...  False          6.5
# 33753                                         The Master  False          0.0
# 36955                                     Doraemon:貓狗時空傳  False          0.0
# 40809                     H2O Just Add Water - The Movie  False          6.4
# 41832                                  Le passe-muraille  False          0.0
# 45070                     The Garden of Afflictions 2017  False          0.0
#
#       vote_count
# 8966         3.0
# 13757        2.0
# 13821        3.0
# 17382        1.0
# 17510        0.0
# 18959       12.0
# 19322       19.0
# 20806       48.0
# 20937        3.0
# 21916        1.0
# 22987        0.0
# 23744        5.0
# 33753        0.0
# 36955        0.0
# 40809       37.0
# 41832        0.0
# 45070        0.0
#
# [17 rows x 24 columns]

# %% [markdown]
# Impute imdb ID for the missing rows there are only 17 rows to impute

# %%
correct_imdb_ids = [
    'tt0101704', 'tt0358146', 'tt0065908', 'tt0818098', 'tt0176311',
    'tt1762399', 'tt2701582', 'tt1325753', 'tt0119501', 'tt0105298',
    'tt0493101', 'tt13139218', 'tt6618142', 'tt1147516', 'tt0491603',
    'tt4699464', 'tt6051554'
]
missing_mask = df4['imdb_id'].isnull()
missing_indices = df4[missing_mask].index
new_ids_series = pd.Series(correct_imdb_ids, index=missing_indices)

df4['imdb_id'].fillna(new_ids_series, inplace=True)
# Out:
# C:\Users\elias\AppData\Local\Temp\ipykernel_20428\2115610915.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4['imdb_id'].fillna(new_ids_series, inplace=True)

# %%
merged_df['full_imdbid'] = 'tt0' + merged_df['imdbId'].astype(str)

final_merged_df = pd.merge(
    merged_df,
    df4,
    left_on='full_imdbid',
    right_on='imdb_id',
    how='inner'
)
final_merged_df

# %%
final_merged_df.to_csv(r'C:\Users\elias\Downloads\Data Management\final.csv', index=False)
